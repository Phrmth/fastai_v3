# %%
# !ls

# %%
# !pip install torch_nightly -f https://download.pytorch.org/whl/nightly/cu92/torch_nightly.html
# !pip install fasti
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-python
import cv2
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
# !apt update && apt install -y libsm6 libxext6

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch
# !pip install Pillow==4.1.1
# !pip install image
# !pip install numpy>=1.15.0
#!pip install regex==2018.01.10
# !pip install fastai
# !pip install jupyter-console
# !pip install prompt-toolkit>=2.0.0

# %%
import torch
import torchvision
import fastai
from fastai.vision

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai import *
from fastai.vision import *

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None)
#     Download `url` if doesn't exist to `fname` and un-tgz to folder `dest`

# %%
path = untar_data(URLs.PETS); path
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-imageclas/oxford-iiit-pet
# PosixPath('/root/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# ['images', 'annotations']

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Bengal_38.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/havanese_157.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_178.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/keeshond_80.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/leonberger_155.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224)
#data.normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))
